# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.plotting.register_matplotlib_converters()

# %%
#fifa_filepath = "../input/fifa.csv"

# Read the file into a variable fifa_data
#fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %% [markdown]
# # Loading the data

# %%
data=pd.read_csv('fifa.csv',index_col="Date")

data
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %% [markdown]
# # Examining the data

# %%
data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# # Plotting data with seaborn

# %%
# set the width and height of the figure

plt.figure(figsize=(15,15))

plt.title(" Fifa Dataset ",fontsize=30)
sns.set_style('dark')
#line chart

sns.lineplot(data=data)
# Out:
# <AxesSubplot:title={'center':' Fifa Dataset '}, xlabel='Date'>

# %%
#list(data.columns)--> list of specific columns

# %% [markdown]
# ## Barchart

# %%
plt.figure(figsize=(10,6))
plt.title('Argentina(ARG)')


sns.barplot(x=data.index,y=data['ARG'])
# Out:
# <AxesSubplot:title={'center':'Argentina(ARG)'}, xlabel='Date', ylabel='ARG'>

# %% [markdown]
# ## HeatMap

# %%
plt.figure(figsize=(20,20))
plt.title("Fifa Dataset")
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
sns.heatmap(data=data,annot=True,annot_kws={"size":18},)
#annot true shows the values on the heatmap
# Out:
# <AxesSubplot:title={'center':'Fifa Dataset'}, ylabel='Date'>

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(x=data['FRA'],y=data['ARG'])
# Out:
# <AxesSubplot:xlabel='FRA', ylabel='ARG'>

# %%
sns.regplot(x=data['ESP'],y=data['ARG'])
# Out:
# <AxesSubplot:xlabel='ESP', ylabel='ARG'>

# %% [markdown]
# ## Histogram

# %%
sns.histplot(data['ARG'])
# Out:
# <AxesSubplot:xlabel='ARG', ylabel='Count'>

# %%
sns.kdeplot(data['ARG'],shade=True)
sns.set_style('dark')

# %% [markdown]
# # Distribution plot

# %%
sns.displot(data['ARG'])

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x ='ESP', y = 'ARG', 
                data = data)
# Out:
# <AxesSubplot:xlabel='ESP', ylabel='ARG'>
